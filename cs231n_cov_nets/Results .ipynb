# %%
import pandas as pd
import numpy as np

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rows = pd.read_csv("results.txt")

# %%
rows.head()
# Out:
#                algo                         params  trainAcc  valAcc
# 0  threeLayerCovnet                        epoch=1      44.2    46.6
# 1  threeLayerCovnet                        epoch=3      57.0    55.7
# 2  threeLayerCovnet              epoch=3-batchNorm      69.8    64.9
# 3  threeLayerCovnet  epoch=3-batchNorm-hyperParams      71.2    65.7

# %%
pd.crosstab(rows.algo, rows.params, aggfunc=np.min, values=rows.valAcc).plot(kind='bar',
         figsize = (20,15), grid=True).legend(
    loc='center left', bbox_to_anchor=(1, 0.5))
