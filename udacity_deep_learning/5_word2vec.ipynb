# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/
https://github.com/thushv89/udacity_deeplearning_complete/blob/master/5_word2vec.py
https://github.com/thushv89/udacity_deeplearning_complete/blob/master/5_word2vec_cbow.py    
http://mccormickml.com/2016/04/27/word2vec-resources/
http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
http://mccormickml.com/2017/01/11/word2vec-tutorial-part-2-negative-sampling/

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /Users/kdalwani/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)

  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0
import pdb
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
       
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)   
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
##    import pdb
##    pdb.set_trace()
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 15000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-17-e023a73e98b8>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:From <ipython-input-17-e023a73e98b8>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.544748
# Nearest to from: merrimack, toltec, giraffe, potions, landsmannschaft, contended, drpg, located,
# Nearest to there: scam, kola, opel, rowena, imi, please, fountains, zef,
# Nearest to state: ubuntu, jermaine, jeux, unharmed, marshallese, palatalization, czar, turbocharged,
# Nearest to people: presumption, romany, antiprism, westphalian, partitions, intoxicated, trickle, architecturally,
# Nearest to were: cognates, helena, herzog, ub, fleischmann, percent, pitch, derivation,
# Nearest to that: greenaway, broadening, jams, salvator, residues, ufo, const, tetrameter,
# Nearest to may: hussites, django, sooty, sosa, araki, adp, aegisthus, satisfied,
# Nearest to all: ayres, soybean, alsos, saving, intercultural, widths, ditch, popping,
# Nearest to four: marking, nazarene, hydrology, asterix, proudly, helmet, yuga, loew,
# Nearest to history: discover, electrically, unjustified, snobol, seanad, maryam, colossus, winfrey,
# Nearest to UNK: moderators, airfoil, impromptu, flushing, plethora, lessons, plano, cultivar,
# Nearest to have: extremism, resuming, invaders, plantagenet, evolution, chronic, gasp, porta,
# Nearest to are: industrial, geneticist, abbas, clarence, clemens, calculations, suede, laodiceans,
# Nearest to he: ambitions, tried, unranked, krill, pickup, mcc, semiconductors, tc,
# Nearest to while: left, indic, hydrate, spider, harmonization, bluegrass, hyperlinks, longitude,
# Nearest to when: hammered, parsley, prog, akm, malawi, pitting, danzig, hatching,
# Average loss at step 2000: 4.580103
# Average loss at step 4000: 4.113708
# Average loss at step 6000: 4.032427
# Average loss at step 8000: 3.929377
# Average loss at step 10000: 3.937679
# Average loss at step 12000: 3.871120
# Average loss at step 14000: 3.736857
# Nearest to from: in, of, to, at, on, for, clanking, whereby,
# Nearest to there: it, opel, hansa, untrue, ja, zionism, usaf, kosrae,
# Nearest to state: palatalization, ubuntu, being, unharmed, agnostics, completeness, czar, premises,
# Nearest to people: presumption, hockey, partitions, socialist, territory, westphalian, straining, severe,
# Nearest to were: are, was, have, tradition, jornal, cognates, both, mitsubishi,
# Nearest to that: which, it, this, not, jeannie, berlioz, to, he,
# Nearest to may: stenosis, to, outsold, felling, prophecy, nnrot, minds, itosu,
# Nearest to all: these, widths, omission, they, manichean, cello, hezekiah, rig,
# Nearest to four: five, seven, six, three, eight, zero, two, nine,
# Nearest to history: tico, discover, colossus, electrically, dignitaries, private, snobol, variance,
# Nearest to UNK: southampton, s, n, blanks, kyrie, dodecahedron, conservationist, al,
# Nearest to have: be, had, has, were, he, clutter, sender, are,
# Nearest to are: were, is, clemens, psoriasis, other, have, include, all,
# Nearest to he: it, they, who, mensheviks, neisse, have, she, later,
# Nearest to while: gershom, hyperlinks, left, svg, indic, croatian, hydrate, millar,
# Nearest to when: computations, akm, he, hatching, pitting, but, malawi, neill,
# Average loss at step 16000: 3.752676
# Average loss at step 18000: 3.846290
# Average loss at step 20000: 3.821532
# Average loss at step 22000: 3.804070
# Average loss at step 24000: 3.805423
# Average loss at step 26000: 3.790093
# Average loss at step 28000: 3.814157
# Average loss at step 30000: 3.810689
# Nearest to from: clanking, at, eubank, autistics, codebreaking, correctness, on, principalities,
# Nearest to there: they, it, zionism, nominates, kosrae, below, questions, pumpkin,
# Nearest to state: forbidding, pete, chestnuts, agnostics, states, tatar, ailment, central,
# Nearest to people: presumption, hockey, medieval, peculiarly, partitions, weekend, clementine, socialist,
# Nearest to were: are, was, have, being, be, had, booby, is,
# Nearest to that: which, this, when, jeannie, what, if, genetic, it,
# Nearest to may: can, would, will, should, could, grapes, nnrot, must,
# Nearest to all: some, these, many, other, omission, hezekiah, their, tipper,
# Nearest to four: five, eight, seven, three, six, two, zero, one,
# Nearest to history: abolishment, tico, private, threonine, episcopalians, discover, news, snegur,
# Nearest to UNK: downwards, lactose, pop, macrolides, avogadro, govt, coincidentally, sailboat,
# Nearest to have: has, had, were, be, are, assigning, tens, originate,
# Nearest to are: were, is, have, all, cake, downwards, include, castration,
# Nearest to he: it, she, who, they, cuyp, ammonium, later, evaluating,
# Nearest to while: pin, but, mesures, slave, unicode, hyperlinks, leg, bluegrass,
# Nearest to when: but, that, if, by, contamination, histological, computations, breakout,
# Average loss at step 32000: 3.815356
# Average loss at step 34000: 3.775337
# Average loss at step 36000: 3.666980
# Average loss at step 38000: 3.752666
# Average loss at step 40000: 3.756839
# Average loss at step 42000: 3.771429
# Average loss at step 44000: 3.761111
# Nearest to from: in, through, into, after, since, principalities, of, at,
# Nearest to there: it, they, zionism, but, typically, he, still, longer,
# Nearest to state: chestnuts, federal, tatar, bangladesh, agnostics, classifies, forbidding, government,
# Nearest to people: presumption, enjoined, conceived, clementine, evo, peculiarly, illustration, bureaucracy,
# Nearest to were: are, was, had, being, been, have, be, assigning,
# Nearest to that: which, it, this, however, what, he, when, not,
# Nearest to may: can, will, would, should, could, must, might, cannot,
# Nearest to all: some, these, hezekiah, humans, several, many, omission, are,
# Nearest to four: six, five, three, seven, eight, zero, two, one,
# Nearest to history: abolishment, list, discover, philosophy, mountbatten, empires, thunderstorms, shuffle,
# Nearest to UNK: mitochondrial, de, hallmark, dodecahedron, challenges, theology, merz, wilde,
# Nearest to have: had, has, be, were, are, algerians, regard, tens,
# Nearest to are: were, is, have, include, many, psoriasis, downwards, some,
# Nearest to he: it, they, she, who, that, but, ammonium, dehydroepiandrosterone,
# Nearest to while: but, with, and, unicode, by, at, in, when,
# Nearest to when: if, but, where, after, because, then, that, while,
# Average loss at step 46000: 3.698813
# Average loss at step 48000: 3.718515
# Average loss at step 50000: 3.773266
# Average loss at step 52000: 3.760443
# Average loss at step 54000: 3.764919
# Average loss at step 56000: 3.750032
# Average loss at step 58000: 3.718170
# Average loss at step 60000: 3.507362
# Nearest to from: and, through, after, in, currents, during, irrational, before,
# Nearest to there: they, it, now, but, these, zionism, longer, still,
# Nearest to state: government, federal, chestnuts, riggs, retire, police, forbidding, assembly,
# Nearest to people: elegantly, encumbered, illustration, antofagasta, evo, medieval, presumption, nairobi,
# Nearest to were: are, was, be, had, have, been, many, earner,
# Nearest to that: which, this, however, what, when, it, where, but,
# Nearest to may: can, would, will, should, could, might, must, cannot,
# Nearest to all: many, some, these, various, several, both, other, any,
# Nearest to four: three, six, five, seven, eight, nine, zero, one,
# Nearest to history: abolishment, empires, list, geography, duplex, mendelevium, asperger, snegur,
# Nearest to UNK: de, n, treasures, cubewanos, lake, subfamilies, casta, motivational,
# Nearest to have: had, has, are, were, having, be, musik, it,
# Nearest to are: were, is, have, include, psoriasis, was, be, all,
# Nearest to he: it, she, they, who, him, later, ammonium, mensheviks,
# Nearest to while: when, but, including, among, although, during, and, after,
# Nearest to when: after, while, where, before, if, because, that, however,
# Average loss at step 62000: 3.749041
# Average loss at step 64000: 3.718135
# Average loss at step 66000: 3.707105
# Average loss at step 68000: 3.746028
# Average loss at step 70000: 3.704630
# Average loss at step 72000: 3.622987
# Average loss at step 74000: 3.702788
# Nearest to from: into, through, after, while, when, before, lipoprotein, principalities,
# Nearest to there: they, it, but, cartridges, zionism, still, uffizi, tydings,
# Nearest to state: mithraism, riggs, city, government, founding, guangzhou, bai, desolation,
# Nearest to people: those, lives, nairobi, encumbered, who, illustration, presumption, antofagasta,
# Nearest to were: are, was, being, had, have, be, been, their,
# Nearest to that: which, however, but, where, this, since, when, it,
# Nearest to may: can, would, will, could, should, must, cannot, might,
# Nearest to all: many, both, several, some, various, these, every, any,
# Nearest to four: five, six, three, seven, eight, two, nine, one,
# Nearest to history: duplex, keenan, inborn, empires, abolishment, episcopalians, warlords, disambiguation,
# Nearest to UNK: la, stiffness, peaking, hardline, et, l, www, rantissi,
# Nearest to have: had, has, were, are, be, having, include, originate,
# Nearest to are: were, is, have, include, assigning, many, including, psoriasis,
# Nearest to he: it, she, they, who, him, never, wiesenthal, mistreated,
# Nearest to while: although, however, when, and, among, including, but, though,
# Nearest to when: because, if, before, while, where, after, but, with,
# Average loss at step 76000: 3.704587
# Average loss at step 78000: 3.745649
# Average loss at step 80000: 3.755962
# Average loss at step 82000: 3.739194
# Average loss at step 84000: 3.709804
# Average loss at step 86000: 3.718318
# Average loss at step 88000: 3.745765
# Average loss at step 90000: 3.622046
# Nearest to from: through, lipoprotein, into, in, peroxides, including, when, brahmic,
# Nearest to there: they, it, he, zionism, still, but, increment, now,
# Nearest to state: government, mithraism, city, founding, riggs, federal, midrashic, states,
# Nearest to people: elegantly, those, presumption, hockey, clementine, jews, multiples, members,
# Nearest to were: are, was, being, have, had, be, mafiosi, earner,
# Nearest to that: which, however, this, where, it, when, but, usually,
# Nearest to may: can, would, could, will, might, must, should, cannot,
# Nearest to all: many, several, various, some, these, signatures, both, any,
# Nearest to four: six, three, eight, seven, five, zero, one, nine,
# Nearest to history: gegen, abolishment, list, warlords, empires, greece, duplex, kimmei,
# Nearest to UNK: haeckel, j, guesses, and, hosted, tut, daily, com,
# Nearest to have: has, had, having, be, were, are, algerians, include,
# Nearest to are: were, is, include, have, assigning, being, be, many,
# Nearest to he: she, it, they, there, later, never, who, dehydroepiandrosterone,
# Nearest to while: when, although, but, however, though, after, since, where,
# Nearest to when: while, where, if, before, after, during, because, at,
# Average loss at step 92000: 3.705631
# Average loss at step 94000: 3.608967
# Average loss at step 96000: 3.695522
# Average loss at step 98000: 3.689909
# Average loss at step 100000: 3.657703

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
