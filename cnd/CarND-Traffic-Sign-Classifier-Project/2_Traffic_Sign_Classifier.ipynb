# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data
DIR = "data/"
training_file = DIR + "train.p"
validation_file= DIR + "valid.p"
testing_file =  DIR + "test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
print ("Train:" + str(X_train.shape))
print ("Valid:" + str(X_valid.shape))
print ("Test: " +  str(X_test.shape))
print ("Label:" + str(y_train.shape))
# Out:
# Train:(34799, 32, 32, 3)
# Valid:(4410, 32, 32, 3)
# Test: (12630, 32, 32, 3)
# Label:(34799,)

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

n_train = X_train.shape[0]

# TODO: Number of testing examples.
n_test = X_test.shape[0]

# TODO: What's the shape of an traffic sign image?
image_shape = X_train.shape[1:]

# TODO: How many unique classes/labels there are in the dataset.
n_classes = len(set(y_train))

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
signs = pd.read_csv("signnames.csv")
id_to_class_name = {}
for class_id in signs["ClassId"].values:
    name= signs[signs["ClassId"] == class_id]
    id_to_class_name[class_id] = (name["SignName"].values[0])
id_to_class_name
# Out:
# {0: 'Speed limit (20km/h)',
#  1: 'Speed limit (30km/h)',
#  2: 'Speed limit (50km/h)',
#  3: 'Speed limit (60km/h)',
#  4: 'Speed limit (70km/h)',
#  5: 'Speed limit (80km/h)',
#  6: 'End of speed limit (80km/h)',
#  7: 'Speed limit (100km/h)',
#  8: 'Speed limit (120km/h)',
#  9: 'No passing',
#  10: 'No passing for vehicles over 3.5 metric tons',
#  11: 'Right-of-way at the next intersection',
#  12: 'Priority road',
#  13: 'Yield',
#  14: 'Stop',
#  15: 'No vehicles',
#  16: 'Vehicles over 3.5 metric tons prohibited',
#  17: 'No entry',
#  18: 'General caution',
#  19: 'Dangerous curve to the left',
#  20: 'Dangerous curve to the right',
#  21: 'Double curve',
#  22: 'Bumpy road',
#  23: 'Slippery road',
#  24: 'Road narrows on the right',
#  25: 'Road work',
#  26: 'Traffic signals',
#  27: 'Pedestrians',
#  28: 'Children crossing',
#  29: 'Bicycles crossing',
#  30: 'Beware of ice/snow',
#  31: 'Wild animals crossing',
#  32: 'End of all speed and passing limits',
#  33: 'Turn right ahead',
#  34: 'Turn left ahead',
#  35: 'Ahead only',
#  36: 'Go straight or right',
#  37: 'Go straight or left',
#  38: 'Keep right',
#  39: 'Keep left',
#  40: 'Roundabout mandatory',
#  41: 'End of no passing',
#  42: 'End of no passing by vehicles over 3.5 metric tons'}

# %% [markdown]
# ## Plot random images

# %%
number_of_class_to_plot = 6
number_of_images_per_class = 5

class_indxs = list(set(y_train))
class_to_plot = np.random.choice(class_indxs, number_of_class_to_plot, replace=False)
fig, ax = plt.subplots(figsize=(12,12))

for y, cls in enumerate(class_to_plot):
    idx = np.flatnonzero(y_train == cls)
    idx = np.random.choice(idx, number_of_images_per_class, replace=False)
    for i, idx in enumerate(idx):
        plt_idx = i * number_of_class_to_plot + y + 1
        plt.subplot(number_of_images_per_class + 1, number_of_class_to_plot, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(class_indxs[cls])
#             plt.title(id_to_class_name[cls])
    plt_idx = (i + 1) * number_of_class_to_plot + y + 1
    plt.subplot(number_of_images_per_class + 1, number_of_class_to_plot, plt_idx)
    mean_image = np.mean(X_train[np.flatnonzero(y_train == cls)], axis=0)
    
    plt.imshow(mean_image.astype('uint8'))

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Number of examples per class

# %%
train_series = pd.Series(y_train)
train_series.value_counts(sort=False).plot(kind='bar')

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
### Preprocess the data here. Preprocessing steps could include normalization, converting to grayscale, etc.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### 2.1 Convert images to float

# %%
# ignore

# %% [markdown]
# ### 2.2. Convert to  gray scale

# %%
def normalize_grayscale(image_data):
    """
    Normalize the image data with Min-Max scaling to a range of [0.1, 0.9]
    :param image_data: The image data to be normalized
    :return: Normalized image data
    """
    return (image_data - 128.0)/128.0

# %%
import cv2

def convert_to_gray_scale(image):
    if image.shape[0] != 32 and image.shape[1] != 32:
        print ("Resizing " + str(image.shape))
        image = cv2.resize(image,(32,32))
    return cv2.cvtColor(image.astype(np.float32), cv2.COLOR_RGB2GRAY)

# %%
def convert_dataset_grayscale(data):
    data_grays = np.ndarray((len(data), 32, 32, 1), dtype=np.float32)
    for index in range(0, len(data)):
        abc = convert_to_gray_scale(data[index])
        data_grays[index] = abc[:,:,  np.newaxis]
    return data_grays

# %%
print ("Convert images to grayscale")
X_train_gray = convert_dataset_grayscale(X_train)
X_valid_gray = convert_dataset_grayscale(X_valid)
X_test_gray = convert_dataset_grayscale(X_test)

print (X_train[10].shape)
print (X_train_gray[10].shape)
print (X_valid_gray[10].shape)

print (X_train[0][0][0][0])
print (X_train_gray[0][0][0][0])
print (type(X_train[0][0][0][0]))
print (type(X_train_gray[0][0][0][0]))
print ("done")
# Out:
# Convert images to grayscale
# (32, 32, 3)
# (32, 32, 1)
# (32, 32, 1)
# 28
# 25.783
# <class 'numpy.uint8'>
# <class 'numpy.float32'>
# done

# %%
print(np.mean(X_train_gray), np.std(X_train_gray))
print(np.mean(X_valid_gray), np.std(X_valid_gray))
# Out:
# 81.9165 66.1339
# 82.7523 68.0585

# %% [markdown]
# ### 2.3. Normalize gray scaled images

# %%
print ("Normalizing grayscaled images...")
X_train_gray_norm = normalize_grayscale(X_train_gray)
X_valid_gray_norm = normalize_grayscale(X_valid_gray)
X_test_gray_norm = normalize_grayscale(X_test_gray)
print ("done")
# Out:
# Normalizing grayscaled images...
# done

# %%
print(np.mean(X_train_gray_norm), np.std(X_train_gray_norm))
print(np.mean(X_valid_gray_norm), np.std(X_valid_gray_norm))
# Out:
# -0.360028 0.516671
# -0.353498 0.531707

# %%
print ((X_train[0][0][0][0]))
print ((X_train_gray[0][0][0][0]))
print ((X_test_gray_norm[0][0][0][0]))
print (type(X_train[0][0][0][0]))
print (type(X_train_gray[0][0][0][0]))
print (type(X_test_gray_norm[0][0][0][0]))
# Out:
# 28
# 25.783
# 0.0633829
# <class 'numpy.uint8'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>

# %%
def plot_original_normalized_image(X_train, X_train_gray, X_normed):
    random_index_image = np.random.randint(len(X_train))
    org = X_train[random_index_image]
    grayed = X_train_gray[random_index_image]
    normed = X_normed[random_index_image]
    print ("Original shape:", org.shape)
    print ("Grap=y shape:", grayed.shape)
    print ("normed shape:", normed.shape) 
    fig, axes = plt.subplots(1, 3, figsize=(12,12))
    print ("Image size:", org.shape)
    print ("Image squeeze:", org.squeeze().shape)

    axes[0].imshow(org)
    axes[0].set_title("Original")
    axes[0].axis('off')
    
    axes[1].imshow(grayed.squeeze(), cmap='gray')
    axes[1].axis('off')
    axes[1].set_title("Grayed")

    axes[2].imshow(normed.squeeze(), cmap='gray')
    axes[2].axis('off')
    axes[2].set_title("Normalized")

plot_original_normalized_image(X_train, X_train_gray, X_train_gray_norm)    

print ("X_Train:", X_train[0][0][0][0])
print ("X_gray:", X_train_gray[0][0][0][0])
print ("X_gray normed:", X_train_gray_norm[0][0][0][0])
# Out:
# Original shape: (32, 32, 3)
# Grap=y shape: (32, 32, 1)
# normed shape: (32, 32, 1)
# Image size: (32, 32, 3)
# Image squeeze: (32, 32, 3)
# X_Train: 28
# X_gray: 25.783
# X_gray normed: -0.79857

# %% [markdown]
# ### Model Architecture

# %%
### Define your architecture here.
### Feel free to use as many code cells as needed.

# %%
import tensorflow as tf

EPOCHS = 15
BATCH_SIZE = 128

print('done')
# Out:
# done

# %%
from tensorflow.contrib.layers import flatten
import tensorflow as tf

def LeNet(x, n_classes):
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    # TODO: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    mu = 0
    sigma = 0.1
    filter_size_layer_1 = 5
    channels = 1
    num_filters = 6

    weights_layer_1 = tf.Variable(tf.truncated_normal(shape=(filter_size_layer_1, filter_size_layer_1, channels,
                                                     num_filters), mean = mu, stddev = sigma))
    base_layer_1 = tf.Variable(tf.zeros(num_filters))
    conv1   = tf.nn.conv2d(x, weights_layer_1, strides=[1, 1, 1, 1], padding='VALID') + base_layer_1

    # TODO: Activation.
    relu_1 = tf.nn.relu(conv1)

    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    # strides = 2, filter size = 2
    layer_1_out = tf.nn.max_pool(relu_1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    weights_layer_2 = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    base_layer_2 = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(layer_1_out, weights_layer_2, strides=[1, 1, 1, 1], padding='VALID') + base_layer_2

    # TODO: Activation.
    relu_2 = tf.nn.relu(conv2)

    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    layer_1_out = tf.nn.max_pool(relu_2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # TODO: Flatten. Input = 5x5x16. Output = 400.
    fc0   = flatten(layer_1_out)

    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    weights_layer_fc0 = tf.Variable(tf.truncated_normal(shape=(400, 120), mean = mu, stddev = sigma))
    base_layer_fc0 = tf.Variable(tf.zeros(120))
    fc1 = tf.matmul(fc0, weights_layer_fc0) + base_layer_fc0

    # TODO: Activation.
    fc1_relu = tf.nn.relu(fc1)

    # Dropout
    fc1_relu = tf.nn.dropout(fc1_relu, keep_prob)

    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    weights_layer_fc1 = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    base_layer_fc1 = tf.Variable(tf.zeros(84))
    fc2 = tf.matmul(fc1_relu, weights_layer_fc1) + base_layer_fc1

    # TODO: Activation.
    fc2_relu = tf.nn.relu(fc2)

    # Dropout
    fc2_relu = tf.nn.dropout(fc2_relu, keep_prob)

    # TODO: Layer 5: Fully Connected. Input = 84. Output = n_classes.
    weights_layer_fc2 = tf.Variable(tf.truncated_normal(shape=(84, n_classes), mean = mu, stddev = sigma))
    base_layer_fc2 = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2_relu, weights_layer_fc2) + base_layer_fc2

    return logits, weights_layer_1, weights_layer_2, weights_layer_fc0, weights_layer_fc1,\
        weights_layer_fc2

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.

# %%
from sklearn.utils import shuffle
tf.reset_default_graph() 

graph = tf.Graph()

with graph.as_default():
    x = tf.placeholder(tf.float32, (None, 32, 32, 1))    
    y = tf.placeholder(tf.int32, (None))
    keep_prob = tf.placeholder(tf.float32) # probability to keep units
    one_hot_y = tf.one_hot(y, 43)
    learning_rate = tf.placeholder(tf.float32) # probability to keep units

    regularied_beta = tf.placeholder(tf.float32)
    
    logits_weights = LeNet(x, n_classes)
    logits = logits_weights[0]
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)

    loss_operation =  tf.reduce_mean(cross_entropy 
        + regularied_beta * tf.nn.l2_loss(logits_weights[1]) 
        + regularied_beta * tf.nn.l2_loss(logits_weights[2])
        + regularied_beta * tf.nn.l2_loss(logits_weights[3]) 
        + regularied_beta * tf.nn.l2_loss(logits_weights[4]))
    
    optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate)
    training_operation = optimizer.minimize(loss_operation)

    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
    accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    def evaluate(X_data, y_data):
        num_examples = len(X_data)
        total_accuracy = 0
        sess = tf.get_default_session()
        for offset in range(0, num_examples, BATCH_SIZE):
            batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
            accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
            total_accuracy += (accuracy * len(batch_x))
        return total_accuracy / num_examples


def run_model_with_cv_params(learning_rate_value, keep_prob_value, regularied_beta_val,
                             X_train_data, y_train_data, X_valid_data, y_valid_data, EPOCHS = 15, verbose = False):
    
    with tf.Session(graph=graph, config=tf.ConfigProto(log_device_placement=True)) as sess:
        sess.run(tf.global_variables_initializer())
        num_examples = len(X_train_data)

        print("Training...")
        print()
        result = {
            
        }
        valid_accuracies = []
        for i in range(EPOCHS):
            X_train_model, y_train_model = shuffle(X_train_data, y_train_data)
            for offset in range(0, num_examples, BATCH_SIZE):
                end = offset + BATCH_SIZE
                batch_x, batch_y = X_train_model[offset:end], y_train_model[offset:end]
                sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, 
                                          keep_prob: keep_prob_value,
                                          learning_rate: learning_rate_value,
                                          regularied_beta: regularied_beta_val
                                       }
                )

            train_accuracy = evaluate(X_train_gray_norm, y_train)
            validation_accuracy = evaluate(X_valid_data, y_valid_data)
            if verbose == True:
                print("EPOCH {} ...".format(i+1))
                print("Train Accuracy = {:.3f}".format(train_accuracy))
                print("Validation Accuracy = {:.3f}".format(validation_accuracy))
                print()
                
                
            valid_accuracies.append(validation_accuracy)

        result['valid_acc'] = valid_accuracies
        return result

# %%
def print_time(start_time, message):
    end_cv_time = time.time()
    total_mins = (end_cv_time - start_time) /(60.0 )
    total_hours = (end_cv_time - start_time) /(60.0 * 60.0 )
    print (message)
    print("\tTotal time taken hours = {:.3f}".format(total_hours))
    print("\tTotal time taken mins = {:.3f}".format(total_mins))

# %%
import pickle
pickled_cv_results_path = "cv_results_2.pkl"

# %%
results_cv = {}

time_per_cv = {}

# %%
results_cv = pickle.load(open(pickled_cv_results_path ,"rb" ))
#print (results_cv.keys())
#results_cv

# %%
import pdb
import time 
l_rates= [0.0009, 0.0001, 0.001, 0.0008, 0.002, 0.01, 0.1]
dropouts = [0.5, 0.1, 0.001, 0.2, 0.4, 0.0, 0.6, 0.8]
betas = [0, 0.001, 0.002, 0.003, 0.01, 0.02, 0.07, 0.1, 0.4, 0.7, 1]

# l_rates= [0.0009]
# dropouts = [0.5, 0.1]
# betas = [0, 0.001]

total_perm = len(l_rates) * len(dropouts) * len(betas)
print ("Total perm", str(total_perm))
start_cv_time = time.time()
index = 0
for r in l_rates:
    for drops in dropouts:
        for beta in betas:
            index += 1
            if (r, drops, beta) not in results_cv:
                start_current_cv_time = time.time()
                print ("****************************************************")
                print (str(index) +  " of " + str(total_perm))
                print ("Running for %.5f, %0.5f, %0.5f, " %(r, drops, beta))
                result = run_model_with_cv_params(r, drops, beta, X_train_gray_norm, y_train, 
                                                  X_valid_gray_norm, y_valid, EPOCHS=12)

                valid_accs = result['valid_acc']
                results_cv[r, drops, beta] = valid_accs[-1]
                print ("Final Accuracy %.5f, " %(valid_accs[-1]))
                end_current_cv_time = time.time()
                time_per_cv[r, drops, beta] = end_current_cv_time - start_current_cv_time
                print_time(start_current_cv_time, "This CV time.")
                print_time(start_cv_time, "So far all CV time.")
                
                print ("****************************************************")
            if (index % 5 == 0):    
                print ("Pickling..")    
                pickle.dump( results_cv, open(pickled_cv_results_path, "wb" ) )                
                print ("done..")    

print ("Pickling..")    
pickle.dump(results_cv, open(pickled_cv_results_path, "wb" ) )                
print ("done..")    

print_time(start_cv_time, "All done")
# Out:
# Total perm 616
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# Pickling..
# done..
# ****************************************************
# 257 of 616
# Running for 0.00100, 0.80000, 0.00300,
# Training...
#
# Final Accuracy 0.94807,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.585
# ****************************************************
# ****************************************************
# 258 of 616
# Running for 0.00100, 0.80000, 0.01000,
# Training...
#
# Final Accuracy 0.92404,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.019
# 	Total time taken mins = 1.165
# ****************************************************
# ****************************************************
# 259 of 616
# Running for 0.00100, 0.80000, 0.02000,
# Training...
#
# Final Accuracy 0.91723,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.029
# 	Total time taken mins = 1.747
# ****************************************************
# ****************************************************
# 260 of 616
# Running for 0.00100, 0.80000, 0.07000,
# Training...
#
# Final Accuracy 0.74263,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 0.039
# 	Total time taken mins = 2.330
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 261 of 616
# Running for 0.00100, 0.80000, 0.10000,
# Training...
#
# Final Accuracy 0.07619,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.048
# 	Total time taken mins = 2.910
# ****************************************************
# ****************************************************
# 262 of 616
# Running for 0.00100, 0.80000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.058
# 	Total time taken mins = 3.490
# ****************************************************
# ****************************************************
# 263 of 616
# Running for 0.00100, 0.80000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.578
# So far all CV time.
# 	Total time taken hours = 0.068
# 	Total time taken mins = 4.068
# ****************************************************
# ****************************************************
# 264 of 616
# Running for 0.00100, 0.80000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.586
# So far all CV time.
# 	Total time taken hours = 0.078
# 	Total time taken mins = 4.654
# ****************************************************
# ****************************************************
# 265 of 616
# Running for 0.00080, 0.50000, 0.00000,
# Training...
#
# Final Accuracy 0.94376,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.593
# So far all CV time.
# 	Total time taken hours = 0.087
# 	Total time taken mins = 5.247
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 266 of 616
# Running for 0.00080, 0.50000, 0.00100,
# Training...
#
# Final Accuracy 0.93492,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.605
# So far all CV time.
# 	Total time taken hours = 0.098
# 	Total time taken mins = 5.852
# ****************************************************
# ****************************************************
# 267 of 616
# Running for 0.00080, 0.50000, 0.00200,
# Training...
#
# Final Accuracy 0.93719,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.108
# 	Total time taken mins = 6.467
# ****************************************************
# ****************************************************
# 268 of 616
# Running for 0.00080, 0.50000, 0.00300,
# Training...
#
# Final Accuracy 0.92336,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.118
# 	Total time taken mins = 7.084
# ****************************************************
# ****************************************************
# 269 of 616
# Running for 0.00080, 0.50000, 0.01000,
# Training...
#
# Final Accuracy 0.89819,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.625
# So far all CV time.
# 	Total time taken hours = 0.128
# 	Total time taken mins = 7.709
# ****************************************************
# ****************************************************
# 270 of 616
# Running for 0.00080, 0.50000, 0.02000,
# Training...
#
# Final Accuracy 0.88186,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.624
# So far all CV time.
# 	Total time taken hours = 0.139
# 	Total time taken mins = 8.332
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 271 of 616
# Running for 0.00080, 0.50000, 0.07000,
# Training...
#
# Final Accuracy 0.34399,
# This CV time.
# 	Total time taken hours = 0.011
# 	Total time taken mins = 0.631
# So far all CV time.
# 	Total time taken hours = 0.149
# 	Total time taken mins = 8.963
# ****************************************************
# ****************************************************
# 272 of 616
# Running for 0.00080, 0.50000, 0.10000,
# Training...
#
# Final Accuracy 0.07324,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.160
# 	Total time taken mins = 9.581
# ****************************************************
# ****************************************************
# 273 of 616
# Running for 0.00080, 0.50000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.170
# 	Total time taken mins = 10.200
# ****************************************************
# ****************************************************
# 274 of 616
# Running for 0.00080, 0.50000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.180
# 	Total time taken mins = 10.818
# ****************************************************
# ****************************************************
# 275 of 616
# Running for 0.00080, 0.50000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.191
# 	Total time taken mins = 11.435
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 276 of 616
# Running for 0.00080, 0.10000, 0.00000,
# Training...
#
# Final Accuracy 0.41383,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.201
# 	Total time taken mins = 12.053
# ****************************************************
# ****************************************************
# 277 of 616
# Running for 0.00080, 0.10000, 0.00100,
# Training...
#
# Final Accuracy 0.34082,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.211
# 	Total time taken mins = 12.668
# ****************************************************
# ****************************************************
# 278 of 616
# Running for 0.00080, 0.10000, 0.00200,
# Training...
#
# Final Accuracy 0.43265,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.221
# 	Total time taken mins = 13.288
# ****************************************************
# ****************************************************
# 279 of 616
# Running for 0.00080, 0.10000, 0.00300,
# Training...
#
# Final Accuracy 0.42925,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.232
# 	Total time taken mins = 13.904
# ****************************************************
# ****************************************************
# 280 of 616
# Running for 0.00080, 0.10000, 0.01000,
# Training...
#
# Final Accuracy 0.31134,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.242
# 	Total time taken mins = 14.520
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 281 of 616
# Running for 0.00080, 0.10000, 0.02000,
# Training...
#
# Final Accuracy 0.14127,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.614
# So far all CV time.
# 	Total time taken hours = 0.252
# 	Total time taken mins = 15.134
# ****************************************************
# ****************************************************
# 282 of 616
# Running for 0.00080, 0.10000, 0.07000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.615
# So far all CV time.
# 	Total time taken hours = 0.262
# 	Total time taken mins = 15.749
# ****************************************************
# ****************************************************
# 283 of 616
# Running for 0.00080, 0.10000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.273
# 	Total time taken mins = 16.366
# ****************************************************
# ****************************************************
# 284 of 616
# Running for 0.00080, 0.10000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.283
# 	Total time taken mins = 16.986
# ****************************************************
# ****************************************************
# 285 of 616
# Running for 0.00080, 0.10000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.293
# 	Total time taken mins = 17.604
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 286 of 616
# Running for 0.00080, 0.10000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.620
# So far all CV time.
# 	Total time taken hours = 0.304
# 	Total time taken mins = 18.224
# ****************************************************
# ****************************************************
# 287 of 616
# Running for 0.00080, 0.00100, 0.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.314
# 	Total time taken mins = 18.841
# ****************************************************
# ****************************************************
# 288 of 616
# Running for 0.00080, 0.00100, 0.00100,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.324
# 	Total time taken mins = 19.457
# ****************************************************
# ****************************************************
# 289 of 616
# Running for 0.00080, 0.00100, 0.00200,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.335
# 	Total time taken mins = 20.074
# ****************************************************
# ****************************************************
# 290 of 616
# Running for 0.00080, 0.00100, 0.00300,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.345
# 	Total time taken mins = 20.691
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 291 of 616
# Running for 0.00080, 0.00100, 0.01000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.355
# 	Total time taken mins = 21.310
# ****************************************************
# ****************************************************
# 292 of 616
# Running for 0.00080, 0.00100, 0.02000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.365
# 	Total time taken mins = 21.927
# ****************************************************
# ****************************************************
# 293 of 616
# Running for 0.00080, 0.00100, 0.07000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.376
# 	Total time taken mins = 22.546
# ****************************************************
# ****************************************************
# 294 of 616
# Running for 0.00080, 0.00100, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.617
# So far all CV time.
# 	Total time taken hours = 0.386
# 	Total time taken mins = 23.163
# ****************************************************
# ****************************************************
# 295 of 616
# Running for 0.00080, 0.00100, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.621
# So far all CV time.
# 	Total time taken hours = 0.396
# 	Total time taken mins = 23.784
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 296 of 616
# Running for 0.00080, 0.00100, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.615
# So far all CV time.
# 	Total time taken hours = 0.407
# 	Total time taken mins = 24.400
# ****************************************************
# ****************************************************
# 297 of 616
# Running for 0.00080, 0.00100, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.620
# So far all CV time.
# 	Total time taken hours = 0.417
# 	Total time taken mins = 25.019
# ****************************************************
# ****************************************************
# 298 of 616
# Running for 0.00080, 0.20000, 0.00000,
# Training...
#
# Final Accuracy 0.67710,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.624
# So far all CV time.
# 	Total time taken hours = 0.427
# 	Total time taken mins = 25.643
# ****************************************************
# ****************************************************
# 299 of 616
# Running for 0.00080, 0.20000, 0.00100,
# Training...
#
# Final Accuracy 0.69569,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.438
# 	Total time taken mins = 26.261
# ****************************************************
# ****************************************************
# 300 of 616
# Running for 0.00080, 0.20000, 0.00200,
# Training...
#
# Final Accuracy 0.70975,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.620
# So far all CV time.
# 	Total time taken hours = 0.448
# 	Total time taken mins = 26.881
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 301 of 616
# Running for 0.00080, 0.20000, 0.00300,
# Training...
#
# Final Accuracy 0.74762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.458
# 	Total time taken mins = 27.497
# ****************************************************
# ****************************************************
# 302 of 616
# Running for 0.00080, 0.20000, 0.01000,
# Training...
#
# Final Accuracy 0.62585,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.616
# So far all CV time.
# 	Total time taken hours = 0.469
# 	Total time taken mins = 28.113
# ****************************************************
# ****************************************************
# 303 of 616
# Running for 0.00080, 0.20000, 0.02000,
# Training...
#
# Final Accuracy 0.57937,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.613
# So far all CV time.
# 	Total time taken hours = 0.479
# 	Total time taken mins = 28.725
# ****************************************************
# ****************************************************
# 304 of 616
# Running for 0.00080, 0.20000, 0.07000,
# Training...
#
# Final Accuracy 0.06871,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.489
# 	Total time taken mins = 29.343
# ****************************************************
# ****************************************************
# 305 of 616
# Running for 0.00080, 0.20000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.619
# So far all CV time.
# 	Total time taken hours = 0.499
# 	Total time taken mins = 29.962
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 306 of 616
# Running for 0.00080, 0.20000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.618
# So far all CV time.
# 	Total time taken hours = 0.510
# 	Total time taken mins = 30.580
# ****************************************************
# ****************************************************
# 307 of 616
# Running for 0.00080, 0.20000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.614
# So far all CV time.
# 	Total time taken hours = 0.520
# 	Total time taken mins = 31.194
# ****************************************************
# ****************************************************
# 308 of 616
# Running for 0.00080, 0.20000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.620
# So far all CV time.
# 	Total time taken hours = 0.530
# 	Total time taken mins = 31.814
# ****************************************************
# ****************************************************
# 309 of 616
# Running for 0.00080, 0.40000, 0.00000,
# Training...
#
# Final Accuracy 0.89274,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.623
# So far all CV time.
# 	Total time taken hours = 0.541
# 	Total time taken mins = 32.437
# ****************************************************
# ****************************************************
# 310 of 616
# Running for 0.00080, 0.40000, 0.00100,
# Training...
#
# Final Accuracy 0.93696,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.620
# So far all CV time.
# 	Total time taken hours = 0.551
# 	Total time taken mins = 33.057
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 311 of 616
# Running for 0.00080, 0.40000, 0.00200,
# Training...
#
# Final Accuracy 0.92018,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.623
# So far all CV time.
# 	Total time taken hours = 0.561
# 	Total time taken mins = 33.679
# ****************************************************
# ****************************************************
# 312 of 616
# Running for 0.00080, 0.40000, 0.00300,
# Training...
#
# Final Accuracy 0.92744,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.624
# So far all CV time.
# 	Total time taken hours = 0.572
# 	Total time taken mins = 34.304
# ****************************************************
# ****************************************************
# 313 of 616
# Running for 0.00080, 0.40000, 0.01000,
# Training...
#
# Final Accuracy 0.87891,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.609
# So far all CV time.
# 	Total time taken hours = 0.582
# 	Total time taken mins = 34.913
# ****************************************************
# ****************************************************
# 314 of 616
# Running for 0.00080, 0.40000, 0.02000,
# Training...
#
# Final Accuracy 0.85760,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.592
# 	Total time taken mins = 35.494
# ****************************************************
# ****************************************************
# 315 of 616
# Running for 0.00080, 0.40000, 0.07000,
# Training...
#
# Final Accuracy 0.07234,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.601
# 	Total time taken mins = 36.074
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 316 of 616
# Running for 0.00080, 0.40000, 0.10000,
# Training...
#
# Final Accuracy 0.06939,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 0.611
# 	Total time taken mins = 36.655
# ****************************************************
# ****************************************************
# 317 of 616
# Running for 0.00080, 0.40000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.621
# 	Total time taken mins = 37.236
# ****************************************************
# ****************************************************
# 318 of 616
# Running for 0.00080, 0.40000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 0.630
# 	Total time taken mins = 37.818
# ****************************************************
# ****************************************************
# 319 of 616
# Running for 0.00080, 0.40000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.640
# 	Total time taken mins = 38.399
# ****************************************************
# ****************************************************
# 320 of 616
# Running for 0.00080, 0.00000, 0.00000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 0.650
# 	Total time taken mins = 38.982
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 321 of 616
# Running for 0.00080, 0.00000, 0.00100,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.659
# 	Total time taken mins = 39.562
# ****************************************************
# ****************************************************
# 322 of 616
# Running for 0.00080, 0.00000, 0.00200,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.669
# 	Total time taken mins = 40.142
# ****************************************************
# ****************************************************
# 323 of 616
# Running for 0.00080, 0.00000, 0.00300,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.679
# 	Total time taken mins = 40.724
# ****************************************************
# ****************************************************
# 324 of 616
# Running for 0.00080, 0.00000, 0.01000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.688
# 	Total time taken mins = 41.305
# ****************************************************
# ****************************************************
# 325 of 616
# Running for 0.00080, 0.00000, 0.02000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 0.698
# 	Total time taken mins = 41.887
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 326 of 616
# Running for 0.00080, 0.00000, 0.07000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.708
# 	Total time taken mins = 42.468
# ****************************************************
# ****************************************************
# 327 of 616
# Running for 0.00080, 0.00000, 0.10000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.577
# So far all CV time.
# 	Total time taken hours = 0.717
# 	Total time taken mins = 43.045
# ****************************************************
# ****************************************************
# 328 of 616
# Running for 0.00080, 0.00000, 0.40000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.577
# So far all CV time.
# 	Total time taken hours = 0.727
# 	Total time taken mins = 43.622
# ****************************************************
# ****************************************************
# 329 of 616
# Running for 0.00080, 0.00000, 0.70000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.577
# So far all CV time.
# 	Total time taken hours = 0.737
# 	Total time taken mins = 44.199
# ****************************************************
# ****************************************************
# 330 of 616
# Running for 0.00080, 0.00000, 1.00000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.746
# 	Total time taken mins = 44.778
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 331 of 616
# Running for 0.00080, 0.60000, 0.00000,
# Training...
#
# Final Accuracy 0.92721,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.756
# 	Total time taken mins = 45.357
# ****************************************************
# ****************************************************
# 332 of 616
# Running for 0.00080, 0.60000, 0.00100,
# Training...
#
# Final Accuracy 0.93197,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.577
# So far all CV time.
# 	Total time taken hours = 0.766
# 	Total time taken mins = 45.934
# ****************************************************
# ****************************************************
# 333 of 616
# Running for 0.00080, 0.60000, 0.00200,
# Training...
#
# Final Accuracy 0.93923,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 0.775
# 	Total time taken mins = 46.517
# ****************************************************
# ****************************************************
# 334 of 616
# Running for 0.00080, 0.60000, 0.00300,
# Training...
#
# Final Accuracy 0.93356,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.785
# 	Total time taken mins = 47.097
# ****************************************************
# ****************************************************
# 335 of 616
# Running for 0.00080, 0.60000, 0.01000,
# Training...
#
# Final Accuracy 0.93084,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.795
# 	Total time taken mins = 47.676
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 336 of 616
# Running for 0.00080, 0.60000, 0.02000,
# Training...
#
# Final Accuracy 0.90159,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.804
# 	Total time taken mins = 48.256
# ****************************************************
# ****************************************************
# 337 of 616
# Running for 0.00080, 0.60000, 0.07000,
# Training...
#
# Final Accuracy 0.64853,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.814
# 	Total time taken mins = 48.834
# ****************************************************
# ****************************************************
# 338 of 616
# Running for 0.00080, 0.60000, 0.10000,
# Training...
#
# Final Accuracy 0.07506,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.824
# 	Total time taken mins = 49.414
# ****************************************************
# ****************************************************
# 339 of 616
# Running for 0.00080, 0.60000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.833
# 	Total time taken mins = 49.993
# ****************************************************
# ****************************************************
# 340 of 616
# Running for 0.00080, 0.60000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.843
# 	Total time taken mins = 50.574
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 341 of 616
# Running for 0.00080, 0.60000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.853
# 	Total time taken mins = 51.155
# ****************************************************
# ****************************************************
# 342 of 616
# Running for 0.00080, 0.80000, 0.00000,
# Training...
#
# Final Accuracy 0.93447,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.862
# 	Total time taken mins = 51.736
# ****************************************************
# ****************************************************
# 343 of 616
# Running for 0.00080, 0.80000, 0.00100,
# Training...
#
# Final Accuracy 0.93469,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.872
# 	Total time taken mins = 52.316
# ****************************************************
# ****************************************************
# 344 of 616
# Running for 0.00080, 0.80000, 0.00200,
# Training...
#
# Final Accuracy 0.93696,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.882
# 	Total time taken mins = 52.896
# ****************************************************
# ****************************************************
# 345 of 616
# Running for 0.00080, 0.80000, 0.00300,
# Training...
#
# Final Accuracy 0.93492,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.891
# 	Total time taken mins = 53.476
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 346 of 616
# Running for 0.00080, 0.80000, 0.01000,
# Training...
#
# Final Accuracy 0.92608,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 0.901
# 	Total time taken mins = 54.055
# ****************************************************
# ****************************************************
# 347 of 616
# Running for 0.00080, 0.80000, 0.02000,
# Training...
#
# Final Accuracy 0.84354,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.911
# 	Total time taken mins = 54.636
# ****************************************************
# ****************************************************
# 348 of 616
# Running for 0.00080, 0.80000, 0.07000,
# Training...
#
# Final Accuracy 0.71791,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.920
# 	Total time taken mins = 55.216
# ****************************************************
# ****************************************************
# 349 of 616
# Running for 0.00080, 0.80000, 0.10000,
# Training...
#
# Final Accuracy 0.07324,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.930
# 	Total time taken mins = 55.797
# ****************************************************
# ****************************************************
# 350 of 616
# Running for 0.00080, 0.80000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.940
# 	Total time taken mins = 56.376
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 351 of 616
# Running for 0.00080, 0.80000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.949
# 	Total time taken mins = 56.956
# ****************************************************
# ****************************************************
# 352 of 616
# Running for 0.00080, 0.80000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.959
# 	Total time taken mins = 57.537
# ****************************************************
# ****************************************************
# 353 of 616
# Running for 0.00200, 0.50000, 0.00000,
# Training...
#
# Final Accuracy 0.94694,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.969
# 	Total time taken mins = 58.118
# ****************************************************
# ****************************************************
# 354 of 616
# Running for 0.00200, 0.50000, 0.00100,
# Training...
#
# Final Accuracy 0.95170,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 0.978
# 	Total time taken mins = 58.701
# ****************************************************
# ****************************************************
# 355 of 616
# Running for 0.00200, 0.50000, 0.00200,
# Training...
#
# Final Accuracy 0.95556,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 0.988
# 	Total time taken mins = 59.282
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 356 of 616
# Running for 0.00200, 0.50000, 0.00300,
# Training...
#
# Final Accuracy 0.95420,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 0.998
# 	Total time taken mins = 59.863
# ****************************************************
# ****************************************************
# 357 of 616
# Running for 0.00200, 0.50000, 0.01000,
# Training...
#
# Final Accuracy 0.91361,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.007
# 	Total time taken mins = 60.444
# ****************************************************
# ****************************************************
# 358 of 616
# Running for 0.00200, 0.50000, 0.02000,
# Training...
#
# Final Accuracy 0.89728,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.017
# 	Total time taken mins = 61.024
# ****************************************************
# ****************************************************
# 359 of 616
# Running for 0.00200, 0.50000, 0.07000,
# Training...
#
# Final Accuracy 0.07642,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.027
# 	Total time taken mins = 61.605
# ****************************************************
# ****************************************************
# 360 of 616
# Running for 0.00200, 0.50000, 0.10000,
# Training...
#
# Final Accuracy 0.07324,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.036
# 	Total time taken mins = 62.185
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 361 of 616
# Running for 0.00200, 0.50000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.046
# 	Total time taken mins = 62.766
# ****************************************************
# ****************************************************
# 362 of 616
# Running for 0.00200, 0.50000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.578
# So far all CV time.
# 	Total time taken hours = 1.056
# 	Total time taken mins = 63.344
# ****************************************************
# ****************************************************
# 363 of 616
# Running for 0.00200, 0.50000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.578
# So far all CV time.
# 	Total time taken hours = 1.065
# 	Total time taken mins = 63.923
# ****************************************************
# ****************************************************
# 364 of 616
# Running for 0.00200, 0.10000, 0.00000,
# Training...
#
# Final Accuracy 0.35986,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.075
# 	Total time taken mins = 64.503
# ****************************************************
# ****************************************************
# 365 of 616
# Running for 0.00200, 0.10000, 0.00100,
# Training...
#
# Final Accuracy 0.41497,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.085
# 	Total time taken mins = 65.083
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 366 of 616
# Running for 0.00200, 0.10000, 0.00200,
# Training...
#
# Final Accuracy 0.36961,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.094
# 	Total time taken mins = 65.664
# ****************************************************
# ****************************************************
# 367 of 616
# Running for 0.00200, 0.10000, 0.00300,
# Training...
#
# Final Accuracy 0.25941,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.104
# 	Total time taken mins = 66.243
# ****************************************************
# ****************************************************
# 368 of 616
# Running for 0.00200, 0.10000, 0.01000,
# Training...
#
# Final Accuracy 0.25147,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 1.114
# 	Total time taken mins = 66.825
# ****************************************************
# ****************************************************
# 369 of 616
# Running for 0.00200, 0.10000, 0.02000,
# Training...
#
# Final Accuracy 0.17710,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.123
# 	Total time taken mins = 67.405
# ****************************************************
# ****************************************************
# 370 of 616
# Running for 0.00200, 0.10000, 0.07000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.133
# 	Total time taken mins = 67.983
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 371 of 616
# Running for 0.00200, 0.10000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.143
# 	Total time taken mins = 68.562
# ****************************************************
# ****************************************************
# 372 of 616
# Running for 0.00200, 0.10000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.578
# So far all CV time.
# 	Total time taken hours = 1.152
# 	Total time taken mins = 69.140
# ****************************************************
# ****************************************************
# 373 of 616
# Running for 0.00200, 0.10000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.578
# So far all CV time.
# 	Total time taken hours = 1.162
# 	Total time taken mins = 69.718
# ****************************************************
# ****************************************************
# 374 of 616
# Running for 0.00200, 0.10000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.172
# 	Total time taken mins = 70.298
# ****************************************************
# ****************************************************
# 375 of 616
# Running for 0.00200, 0.00100, 0.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 1.181
# 	Total time taken mins = 70.880
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 376 of 616
# Running for 0.00200, 0.00100, 0.00100,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.191
# 	Total time taken mins = 71.460
# ****************************************************
# ****************************************************
# 377 of 616
# Running for 0.00200, 0.00100, 0.00200,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.201
# 	Total time taken mins = 72.040
# ****************************************************
# ****************************************************
# 378 of 616
# Running for 0.00200, 0.00100, 0.00300,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 1.210
# 	Total time taken mins = 72.620
# ****************************************************
# ****************************************************
# 379 of 616
# Running for 0.00200, 0.00100, 0.01000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.220
# 	Total time taken mins = 73.198
# ****************************************************
# ****************************************************
# 380 of 616
# Running for 0.00200, 0.00100, 0.02000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.230
# 	Total time taken mins = 73.778
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 381 of 616
# Running for 0.00200, 0.00100, 0.07000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.239
# 	Total time taken mins = 74.359
# ****************************************************
# ****************************************************
# 382 of 616
# Running for 0.00200, 0.00100, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.249
# 	Total time taken mins = 74.938
# ****************************************************
# ****************************************************
# 383 of 616
# Running for 0.00200, 0.00100, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.259
# 	Total time taken mins = 75.519
# ****************************************************
# ****************************************************
# 384 of 616
# Running for 0.00200, 0.00100, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.579
# So far all CV time.
# 	Total time taken hours = 1.268
# 	Total time taken mins = 76.099
# ****************************************************
# ****************************************************
# 385 of 616
# Running for 0.00200, 0.00100, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.278
# 	Total time taken mins = 76.680
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 386 of 616
# Running for 0.00200, 0.20000, 0.00000,
# Training...
#
# Final Accuracy 0.63379,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 1.288
# 	Total time taken mins = 77.262
# ****************************************************
# ****************************************************
# 387 of 616
# Running for 0.00200, 0.20000, 0.00100,
# Training...
#
# Final Accuracy 0.72766,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 1.297
# 	Total time taken mins = 77.843
# ...
# ****************************************************
# 573 of 616
# Running for 0.10000, 0.40000, 0.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.099
# 	Total time taken mins = 185.945
# ****************************************************
# ****************************************************
# 574 of 616
# Running for 0.10000, 0.40000, 0.00100,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.109
# 	Total time taken mins = 186.525
# ****************************************************
# ****************************************************
# 575 of 616
# Running for 0.10000, 0.40000, 0.00200,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.118
# 	Total time taken mins = 187.106
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 576 of 616
# Running for 0.10000, 0.40000, 0.00300,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.128
# 	Total time taken mins = 187.686
# ****************************************************
# ****************************************************
# 577 of 616
# Running for 0.10000, 0.40000, 0.01000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.138
# 	Total time taken mins = 188.267
# ****************************************************
# ****************************************************
# 578 of 616
# Running for 0.10000, 0.40000, 0.02000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.147
# 	Total time taken mins = 188.849
# ****************************************************
# ****************************************************
# 579 of 616
# Running for 0.10000, 0.40000, 0.07000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.157
# 	Total time taken mins = 189.429
# ****************************************************
# ****************************************************
# 580 of 616
# Running for 0.10000, 0.40000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.167
# 	Total time taken mins = 190.009
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 581 of 616
# Running for 0.10000, 0.40000, 0.40000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.176
# 	Total time taken mins = 190.590
# ****************************************************
# ****************************************************
# 582 of 616
# Running for 0.10000, 0.40000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.186
# 	Total time taken mins = 191.170
# ****************************************************
# ****************************************************
# 583 of 616
# Running for 0.10000, 0.40000, 1.00000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.196
# 	Total time taken mins = 191.751
# ****************************************************
# ****************************************************
# 584 of 616
# Running for 0.10000, 0.00000, 0.00000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.206
# 	Total time taken mins = 192.333
# ****************************************************
# ****************************************************
# 585 of 616
# Running for 0.10000, 0.00000, 0.00100,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.215
# 	Total time taken mins = 192.915
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 586 of 616
# Running for 0.10000, 0.00000, 0.00200,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.225
# 	Total time taken mins = 193.495
# ****************************************************
# ****************************************************
# 587 of 616
# Running for 0.10000, 0.00000, 0.00300,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.235
# 	Total time taken mins = 194.076
# ****************************************************
# ****************************************************
# 588 of 616
# Running for 0.10000, 0.00000, 0.01000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.244
# 	Total time taken mins = 194.656
# ****************************************************
# ****************************************************
# 589 of 616
# Running for 0.10000, 0.00000, 0.02000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.254
# 	Total time taken mins = 195.237
# ****************************************************
# ****************************************************
# 590 of 616
# Running for 0.10000, 0.00000, 0.07000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.264
# 	Total time taken mins = 195.819
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 591 of 616
# Running for 0.10000, 0.00000, 0.10000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 3.273
# 	Total time taken mins = 196.401
# ****************************************************
# ****************************************************
# 592 of 616
# Running for 0.10000, 0.00000, 0.40000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.283
# 	Total time taken mins = 196.982
# ****************************************************
# ****************************************************
# 593 of 616
# Running for 0.10000, 0.00000, 0.70000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.293
# 	Total time taken mins = 197.563
# ****************************************************
# ****************************************************
# 594 of 616
# Running for 0.10000, 0.00000, 1.00000,
# Training...
#
# Final Accuracy 0.00680,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.302
# 	Total time taken mins = 198.145
# ****************************************************
# ****************************************************
# 595 of 616
# Running for 0.10000, 0.60000, 0.00000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.584
# So far all CV time.
# 	Total time taken hours = 3.312
# 	Total time taken mins = 198.730
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 596 of 616
# Running for 0.10000, 0.60000, 0.00100,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 3.322
# 	Total time taken mins = 199.312
# ****************************************************
# ****************************************************
# 597 of 616
# Running for 0.10000, 0.60000, 0.00200,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.584
# So far all CV time.
# 	Total time taken hours = 3.332
# 	Total time taken mins = 199.897
# ****************************************************
# ****************************************************
# 598 of 616
# Running for 0.10000, 0.60000, 0.00300,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.341
# 	Total time taken mins = 200.479
# ****************************************************
# ****************************************************
# 599 of 616
# Running for 0.10000, 0.60000, 0.01000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.351
# 	Total time taken mins = 201.061
# ****************************************************
# ****************************************************
# 600 of 616
# Running for 0.10000, 0.60000, 0.02000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.361
# 	Total time taken mins = 201.643
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 601 of 616
# Running for 0.10000, 0.60000, 0.07000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.370
# 	Total time taken mins = 202.225
# ****************************************************
# ****************************************************
# 602 of 616
# Running for 0.10000, 0.60000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.380
# 	Total time taken mins = 202.808
# ****************************************************
# ****************************************************
# 603 of 616
# Running for 0.10000, 0.60000, 0.40000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.390
# 	Total time taken mins = 203.389
# ****************************************************
# ****************************************************
# 604 of 616
# Running for 0.10000, 0.60000, 0.70000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.584
# So far all CV time.
# 	Total time taken hours = 3.400
# 	Total time taken mins = 203.973
# ****************************************************
# ****************************************************
# 605 of 616
# Running for 0.10000, 0.60000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.584
# So far all CV time.
# 	Total time taken hours = 3.409
# 	Total time taken mins = 204.557
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 606 of 616
# Running for 0.10000, 0.80000, 0.00000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.581
# So far all CV time.
# 	Total time taken hours = 3.419
# 	Total time taken mins = 205.138
# ****************************************************
# ****************************************************
# 607 of 616
# Running for 0.10000, 0.80000, 0.00100,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.429
# 	Total time taken mins = 205.720
# ****************************************************
# ****************************************************
# 608 of 616
# Running for 0.10000, 0.80000, 0.00200,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.438
# 	Total time taken mins = 206.301
# ****************************************************
# ****************************************************
# 609 of 616
# Running for 0.10000, 0.80000, 0.00300,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.448
# 	Total time taken mins = 206.881
# ****************************************************
# ****************************************************
# 610 of 616
# Running for 0.10000, 0.80000, 0.01000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.583
# So far all CV time.
# 	Total time taken hours = 3.458
# 	Total time taken mins = 207.464
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 611 of 616
# Running for 0.10000, 0.80000, 0.02000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.467
# 	Total time taken mins = 208.044
# ****************************************************
# ****************************************************
# 612 of 616
# Running for 0.10000, 0.80000, 0.07000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.477
# 	Total time taken mins = 208.624
# ****************************************************
# ****************************************************
# 613 of 616
# Running for 0.10000, 0.80000, 0.10000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.487
# 	Total time taken mins = 209.204
# ****************************************************
# ****************************************************
# 614 of 616
# Running for 0.10000, 0.80000, 0.40000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.496
# 	Total time taken mins = 209.784
# ****************************************************
# ****************************************************
# 615 of 616
# Running for 0.10000, 0.80000, 0.70000,
# Training...
#
# Final Accuracy 0.04762,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.580
# So far all CV time.
# 	Total time taken hours = 3.506
# 	Total time taken mins = 210.364
# ****************************************************
# Pickling..
# done..
# ****************************************************
# 616 of 616
# Running for 0.10000, 0.80000, 1.00000,
# Training...
#
# Final Accuracy 0.05442,
# This CV time.
# 	Total time taken hours = 0.010
# 	Total time taken mins = 0.582
# So far all CV time.
# 	Total time taken hours = 3.516
# 	Total time taken mins = 210.946
# ****************************************************
# Pickling..
# done..
# All done
# 	Total time taken hours = 3.516
# 	Total time taken mins = 210.946

# %%
import time
start_cv_time = time.time()
run_model_with_cv_params(0.0009, 0.5, 0, X_train_gray_norm, y_train, X_valid_gray_norm, y_valid, EPOCHS=3, verbose=True)
end_cv_time = time.time()
total_mins = (end_cv_time - start_cv_time) /(60.0 )

total_hours = (end_cv_time - start_cv_time) /(60.0 * 60.0 )
print("Total time taken hours = {:.3f}".format(total_hours))
print("Total time taken mins = {:.3f}".format(total_mins))
# Out:
# Training...
#
# EPOCH 1 ...
# Train Accuracy = 0.624
# Validation Accuracy = 0.566
#
# EPOCH 2 ...
# Train Accuracy = 0.834
# Validation Accuracy = 0.792
#
# EPOCH 3 ...
# Train Accuracy = 0.890
# Validation Accuracy = 0.854
#
# Total time taken hours = 0.011
# Total time taken mins = 0.676

# %%
print (end_cv_time - start_cv_time)
print (start_cv_time)
# Out:
# 40.58386492729187
# 1491183775.409989

# %% [markdown]
# ### Best model

# %%
# Print out results.
best_val = -1
best_params = None

for keys in sorted(results_cv):
    (r, drops, beta) = keys
    accuray_val = results_cv[keys]
    print ('learning rate:%e, drop out:%e, beta: %e' % (r, drops ,beta))
    if best_val == -1 or accuray_val  > best_val:
        best_val = accuray_val
        best_params = keys
    
print ('best validation accuracy achieved during cross-validation: %f' % best_val)
(r, drops, beta) = best_params
print (best_params)

val_accuracies = []
num_drops = []
num_betas = []
num_learning_rate = []

import pandas as pd
for key in sorted(results_cv):
    val_accuracies.append(results_cv[key])
    num_learning_rate.append(key[0])
    num_drops.append(key[1])
    num_betas.append(key[2])
        
d = {'learning_rate' : pd.Series(num_learning_rate),
    'dropout' : pd.Series(num_drops),
     'beta': num_betas,
     'valAccuracy': val_accuracies     
}
rows = pd.DataFrame(d)
# Out:
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-04, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:8.000000e-04, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:9.000000e-04, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-03, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:2.000000e-03, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-02, drop out:8.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:0.000000e+00, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-03, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:1.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:2.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:4.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:5.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:6.000000e-01, beta: 1.000000e+00
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 0.000000e+00
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 1.000000e-03
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 2.000000e-03
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 3.000000e-03
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 1.000000e-02
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 2.000000e-02
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 7.000000e-02
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 1.000000e-01
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 4.000000e-01
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 7.000000e-01
# learning rate:1.000000e-01, drop out:8.000000e-01, beta: 1.000000e+00
# best validation accuracy achieved during cross-validation: 0.958050
# (0.002, 0.8, 0)

# %% [markdown]
# ### best validation accuracy achieved during cross-validation: 0.958050
# ### parameters (0.002, 0.8, 0)

# %% [markdown]
# ## Plot the accuracy for each CV params

# %%
pd.crosstab([rows.beta],[rows.learning_rate ],  
            values=rows.valAccuracy,
            aggfunc=np.max
            ).plot(kind='bar', grid=True,  figsize=(20,20), fontsize=20
            ).legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=20)

# %%
pd.crosstab([rows.dropout],[rows.beta ],  
            values=rows.valAccuracy,
            aggfunc=np.max
            ).plot(kind='bar', grid=True,  figsize=(20,20), fontsize=20
            ).legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=20)

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %%
import os
sample_dir = "data/web_samples/"
test_images_path = os.listdir(sample_dir)
print (test_images_path)
import matplotlib.image as mpimg
# Out:
# ['120_speed.jpeg', '30_speed_bike.jpeg', '50_speed.jpeg', '60 speed.jpeg', 'childer_mother_bicycle.jpeg', 'no_passing_bicycle.jpg', 'pedestrian.jpg', 'right_left_turn.jpeg', 'right_sharp.png', 'right_turn.jpeg', 'round_about_give_way.jpg', 'sharp_right_2.jpeg', 'stop.jpeg']

# %%
image = mpimg.imread(sample_dir + test_images_path[0])
axes[rows][col].imshow(image)

# %%
plt.imshow(image)
plt.axis('off')

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.
import matplotlib.image as mpimg
per_row_image = 3
num_rows = (int)(len(test_images)/per_row_image + 1)
f, axes = plt.subplots(num_rows, per_row_image, figsize=(12,12))
sample_test_images = []
for rows in range(num_rows):
    for col in range(per_row_image):
        index = (rows * per_row_image) + col
        axes[rows][col].axis('off')
        if (index >= len(test_images)):
            continue
        image_path = test_images[index]
        image = mpimg.imread(sample_dir + image_path)
        sample_test_images.append(image)
        axes[rows][col].imshow(image)
        axes[rows][col].set_title(image_path)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
### Run the predictions here and use the model to output the prediction for each image.
### Make sure to pre-process the images with the same pre-processing pipeline used earlier.
### Feel free to use as many code cells as needed.

# %%
def pre_process_pipline(images):
    images_gray = convert_dataset_grayscale(images)
    print (images[0][0][0][0])
    print (images_gray[0][0][0][0])
    print (type(images[0][0][0][0]))
    print (type(images_gray[0][0][0][0]))
    normalized_gray = normalize_grayscale(images_gray)
    return images, images_gray, normalized_gray
    
images, images_gray, normalized_gray = pre_process_pipline(sample_test_images)    

print(np.mean(images_gray), np.std(images_gray))
print(np.mean(normalized_gray), np.std(normalized_gray))
plot_original_normalized_image(images, images_gray, normalized_gray)
# Out:
# Resizing (181, 272, 3)
# Resizing (259, 194, 3)
# Resizing (259, 194, 3)
# Resizing (259, 194, 3)
# Resizing (259, 194, 3)
# Resizing (478, 359, 3)
# Resizing (478, 359, 3)
# Resizing (162, 310, 3)
# Resizing (225, 225, 3)
# Resizing (259, 194, 3)
# Resizing (478, 359, 3)
# Resizing (260, 194, 3)
# Resizing (259, 194, 3)
# 75
# 90.722
# <class 'numpy.uint8'>
# <class 'numpy.float32'>
# 102.38 66.158
# -0.200155 0.51686
# Original shape: (260, 194, 3)
# Grap=y shape: (32, 32, 1)
# normed shape: (32, 32, 1)
# Image size: (260, 194, 3)
# Image squeeze: (260, 194, 3)

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tk.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
#
# ## Step 4: Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it maybe having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")

# %% [markdown]
# ### Question 9
#
# Discuss how you used the visual output of your trained network's feature maps to show that it had learned to look for interesting characteristics in traffic sign images

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.
