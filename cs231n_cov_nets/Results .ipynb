# %%
import pandas as pd
import numpy as np

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/kdalwani/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
rows = pd.read_csv("results.txt")

# %%
rows.head()
# Out:
#    grpIndex         algo update  epoch batchNorm            params  trainAcc  \
# 0         1          knn    ABC     -1        No              k=12     27.00
# 1         2          svm    SGD     -1        No               SGD     39.08
# 2         3      softMax    SGD     -1        No       hyperParams     32.92
# 3         4  twoLayerNet    SGD     -1        No       hyperParams     49.27
# 4         2          svm    SGD     -1        No  imageHistFeature     42.09
#
#    valAcc  testAcc
# 0    25.6      NaN
# 1    39.0    37.90
# 2    34.6      NaN
# 3    49.0    46.30
# 4    43.9    41.11

# %%
pd.crosstab([rows.grpIndex, rows.algo], [rows.params], aggfunc=np.max, 
            values=rows.valAcc, margins=False).plot(kind='bar', sort_columns=True, rot=0, 
         figsize = (15,10), grid=True, title="Validation accuracy for various algorithms").legend(
    loc='center left', bbox_to_anchor=(1, 0.5))

# %%
pd.crosstab([rows.grpIndex,rows.algo], rows.params, aggfunc=np.max ,
            values=rows.valAcc, margins=False).plot(kind='bar', sort_columns=True,
         figsize = (20,20), grid=True).legend(
    loc='center left', bbox_to_anchor=(1, 0.5))

# %%
ax = rows.sort_values(['grpIndex', 'valAcc']).plot(x='algo', y='valAcc', grid=True, 
  figsize=(15, 8), title="Validation accuracy for different algorithm.", marker='o', linestyle='--',)
ax.set(xlabel="Algorithms.")
ax.set(ylabel="Validtaion Accuracy.")
